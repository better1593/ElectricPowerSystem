# %%
import pandas as pd

from Model import Strategy
from Model.Network import Network
import matplotlib.pyplot as plt
import numpy as np

if __name__ == '__main__':
    # 1. 接收到创建新电网指令
    file_name = "01_8"
    varied_frequency = np.arange(0, 37, 9)
    network = Network()
    network.run(file_name)
    print(network.solution)
    print(network.measurement)
# Out:
# Tower:tower_1 loaded.
# Tower:tower_2 loaded.
# OHL:OHL_1 loaded.
# ------------------------------------------------
# Tower:tower_1 building...
# ------------------------------------------------
# A_tower matrix is building...
# A_tower matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# R_tower matrix is building...
# R_tower matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# L_tower matrix is building...
# L_tower matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# P_tower matrix is building...
# P matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# C_tower matrix is building...
# C_tower matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# G_tower matrix is building...
# G matrix is built successfully
# ------------------------------------------------
# Tower:tower_1  building is completed.
# ------------------------------------------------
# ------------------------------------------------
# Tower:tower_2 building...
# ------------------------------------------------
# A_tower matrix is building...
# A_tower matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# R_tower matrix is building...
# R_tower matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# L_tower matrix is building...
# L_tower matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# P_tower matrix is building...
# P matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# C_tower matrix is building...
# C_tower matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# G_tower matrix is building...
# G matrix is built successfully
# ------------------------------------------------
# Tower:tower_2  building is completed.
# ------------------------------------------------
# ------------------------------------------------
# OHL:OHL_1 building...
# ------------------------------------------------
# A_OHL matrix is building...
# A_OHL matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# R matrix is building...
# R_OHL matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# L_OHL matrix is building...
# L_OHL matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# C_OHL matrix is building...
# C_OHL matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# G_OHL matrix is building...
# G_OHL matrix is built successfully
# ------------------------------------------------
# ------------------------------------------------
# Z_OHL matrix is building...
# Z_OHL matrix is built successfully
# ------------------------------------------------
# OHL:OHL_1 building is completed.
# ------------------------------------------------
# /Users/xueting/gitlab/ElectricPowerSystem/Function/Calculators/Inductance.py:363: RuntimeWarning: invalid value encountered in divide
#   u = np.array(ls * ((2 * lf2 * (R22 - R32 - ls2) + a2 * (R42 - R32 - lf2)) / DIS))
# /Users/xueting/gitlab/ElectricPowerSystem/Function/Calculators/Inductance.py:364: RuntimeWarning: invalid value encountered in divide
#   v = (lf * ((2 * ls2 * (R42 - R32 - lf2) + a2 * (R22 - R32 - ls2)) / DIS))
# /Users/xueting/gitlab/ElectricPowerSystem/Function/Calculators/Inductance.py:409: RuntimeWarning: invalid value encountered in divide
#   tp0 = OMG * d / sine
# /Users/xueting/gitlab/ElectricPowerSystem/Function/Calculators/Inductance.py:363: RuntimeWarning: invalid value encountered in divide
#   u = np.array(ls * ((2 * lf2 * (R22 - R32 - ls2) + a2 * (R42 - R32 - lf2)) / DIS))
# /Users/xueting/gitlab/ElectricPowerSystem/Function/Calculators/Inductance.py:364: RuntimeWarning: invalid value encountered in divide
#   v = (lf * ((2 * ls2 * (R42 - R32 - lf2) + a2 * (R22 - R32 - ls2)) / DIS))
# /Users/xueting/gitlab/ElectricPowerSystem/Function/Calculators/Inductance.py:409: RuntimeWarning: invalid value encountered in divide
#   tp0 = OMG * d / sine
# -----------------S T A R T--------------------------
# ****Stacking matrix elements (lower triangle) into single column ...
# ****Fitting column ...
#    Iter 1
#    Iter 2
#    Iter 3
#    Iter 4
#    Iter 5
# ****Generating pole-residue model ...
# -------------------E N D----------------------------
# -----------------S T A R T--------------------------
# *** Y-PARAMETERS ***
#
#   [ 0  0 ]
#   Passivity Assessment:
#
# -->Passivity was successfully enforced.
#    Max. violation, eig(G) :  None
#    Max. violation, eig(D) :  None
#    Max. violation, eig(E) :  None
# Time summary:
#    Passivity assessment : 0.0006661415100097656 sec
#    Passivity enforcement: 0 sec
#    Total: 0 sec
# -------------------E N D----------------------------
# Nonlinear calculation is used
# you are measuring
#           0             1             2             3             4     \
# X01        0.0  1.084935e-06 -1.878932e-07  2.344775e-06 -9.254737e-06
# X01_OHL    0.0  1.084933e-06 -1.878908e-07  2.344771e-06 -9.254722e-06
# X02        0.0 -1.181522e-06  3.309285e-07 -2.967192e-06  1.000806e-05
# X02_OHL    0.0 -1.181521e-06  3.309249e-07 -2.967185e-06  1.000804e-05
# X03        0.0  1.234309e-06 -9.732088e-07  3.064218e-06 -1.214258e-05
# ...        ...           ...           ...           ...           ...
# Y_T12O_S   0.0 -1.192846e-08  1.262608e-08 -2.718474e-08  1.239832e-07
# Y_T22O_A   0.0  1.481677e-08 -2.035554e-08  4.183448e-08 -1.663229e-07
# Y_T22O_B   0.0 -1.588062e-08  2.680109e-08 -5.133420e-08  1.915115e-07
# Y_T22O_C   0.0  1.424256e-08 -1.929825e-08  3.999573e-08 -1.593788e-07
# Y_T22O_S   0.0 -1.192846e-08  1.262608e-08 -2.718474e-08  1.239832e-07
#
#                   5         6         7         8         9     ...  \
# X01       3.308806e-05 -0.000125  0.000465 -0.001736  0.006479  ...
# X01_OHL   3.308800e-05 -0.000125  0.000465 -0.001736  0.006479  ...
# X02      -3.834475e-05  0.000142 -0.000531  0.001980 -0.007390  ...
# X02_OHL  -3.834467e-05  0.000142 -0.000531  0.001980 -0.007390  ...
# X03       4.465885e-05 -0.000167  0.000624 -0.002329  0.008691  ...
# ...                ...       ...       ...       ...       ...  ...
# Y_T12O_S -4.532963e-07  0.000002 -0.000006  0.000024 -0.000088  ...
# Y_T22O_A  6.183426e-07 -0.000002  0.000009 -0.000032  0.000120  ...
# Y_T22O_B -7.168541e-07  0.000003 -0.000010  0.000037 -0.000139  ...
# Y_T22O_C  5.918031e-07 -0.000002  0.000008 -0.000031  0.000115  ...
# Y_T22O_S -4.532963e-07  0.000002 -0.000006  0.000024 -0.000088  ...
#
#                   1991          1992          1993          1994  \
